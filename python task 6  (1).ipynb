# %%
import pandas as pd

# %%
df=pd.read_csv("financial_dataset.csv")

# %%
df
# Out:
#       Transaction_ID Customer_ID Customer_Name     Category    Sales  Profit  \
# 0              11317    CUST1134        Anjali    Furniture   1875.0  4126.0
# 1              11001    CUST1177         Sneha   Stationery  32521.0  9290.0
# 2              11069    CUST1478         Sneha         food   8948.0  8683.0
# 3              11968    CUST1016         Priya    Furniture  20072.0  8320.0
# 4              10530    CUST1321         Priya   Stationery  32943.0  9336.0
# ...              ...         ...           ...          ...      ...     ...
# 1995           10700    CUST1427         Rahul  Electronics  14407.0  9016.0
# 1996           11500    CUST1136          Neha  Electronics   2105.0  5292.0
# 1997           11706    CUST1247         Vivek         Food  35927.0  2756.0
# 1998           10511    CUST1299         Rahul    Furniture  48447.0  1654.0
# 1999           11083    CUST1075          Arun     Clothing   8433.0  4718.0
#
# ...

# %%
df.head()
# Out:
#    Transaction_ID Customer_ID Customer_Name    Category    Sales  Profit  \
# 0           11317    CUST1134        Anjali   Furniture   1875.0  4126.0
# 1           11001    CUST1177         Sneha  Stationery  32521.0  9290.0
# 2           11069    CUST1478         Sneha        food   8948.0  8683.0
# 3           11968    CUST1016         Priya   Furniture  20072.0  8320.0
# 4           10530    CUST1321         Priya  Stationery  32943.0  9336.0
#
#    Quantity Payment_Status       City     Transaction_Date
# 0        16        Pending     Mumbai  2026-10-21 00:00:00
# 1        13           Paid  Bangalore  2026-05-16 00:00:00
# 2         3         Unpaid    Chennai  2026-06-19 00:00:00
# 3         1        Pending     Mumbai  2027-09-11 12:00:00
# 4         3           Paid  Bangalore  2025-09-22 12:00:00

# %%
df.tail()
# Out:
#       Transaction_ID Customer_ID Customer_Name     Category    Sales  Profit  \
# 1995           10700    CUST1427         Rahul  Electronics  14407.0  9016.0
# 1996           11500    CUST1136          Neha  Electronics   2105.0  5292.0
# 1997           11706    CUST1247         Vivek         Food  35927.0  2756.0
# 1998           10511    CUST1299         Rahul    Furniture  48447.0  1654.0
# 1999           11083    CUST1075          Arun     Clothing   8433.0  4718.0
#
#       Quantity Payment_Status       City     Transaction_Date
# 1995         8           paid  Bangalore  2025-12-16 12:00:00
# 1996        13         Unpaid      Delhi  2027-01-20 12:00:00
# 1997         5        Pending  Mangalore  2027-05-03 12:00:00
# 1998         7         Unpaid      Delhi  2025-09-13 00:00:00
# 1999         5        Pending      Kochi  2026-06-26 00:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    2000 non-null   int64
#  1   Customer_ID       2000 non-null   object
#  2   Customer_Name     2000 non-null   object
#  3   Category          1977 non-null   object
#  4   Sales             1967 non-null   float64
#  5   Profit            1970 non-null   float64
#  6   Quantity          2000 non-null   int64
#  7   Payment_Status    2000 non-null   object
#  8   City              1979 non-null   object
#  9   Transaction_Date  2000 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 156.4+ KB

# %%
df.describe()
# Out:
#        Transaction_ID         Sales        Profit    Quantity
# count     2000.000000   1967.000000   1970.000000  2000.00000
# mean     11001.443500  25147.046263   3469.098985    10.18850
# std        578.772536  14375.624741   4923.386360     5.52958
# min      10001.000000    516.000000  -4982.000000     1.00000
# 25%      10502.750000  12723.500000   -812.500000     5.00000
# 50%      10998.500000  25200.000000   3526.000000    10.00000
# 75%      11504.250000  37545.000000   7711.250000    15.00000
# max      12000.000000  49923.000000  11988.000000    19.00000

# %%
df.shape
# Out:
# (2000, 10)

# %%
df.isnull().sum()
# Out:
# Transaction_ID       0
# Customer_ID          0
# Customer_Name        0
# Category            23
# Sales               33
# Profit              30
# Quantity             0
# Payment_Status       0
# City                21
# Transaction_Date     0
# dtype: int64

# %%
df["Category"]
# Out:
# 0         Furniture
# 1        Stationery
# 2              food
# 3         Furniture
# 4        Stationery
#            ...
# 1995    Electronics
# 1996    Electronics
# 1997           Food
# 1998      Furniture
# 1999       Clothing
# Name: Category, Length: 2000, dtype: object

# %%
df["Category"].mode()
# Out:
# 0    Clothing
# Name: Category, dtype: object

# %%
df["Category"].fillna(0)
# Out:
# 0         Furniture
# 1        Stationery
# 2              food
# 3         Furniture
# 4        Stationery
#            ...
# 1995    Electronics
# 1996    Electronics
# 1997           Food
# 1998      Furniture
# 1999       Clothing
# Name: Category, Length: 2000, dtype: object

# %%
df["Category"]=df["Category"].fillna(df["Category"].mode()[0])

# %%
df["Category"]
# Out:
# 0         Furniture
# 1        Stationery
# 2              food
# 3         Furniture
# 4        Stationery
#            ...
# 1995    Electronics
# 1996    Electronics
# 1997           Food
# 1998      Furniture
# 1999       Clothing
# Name: Category, Length: 2000, dtype: object

# %%
df["Sales"]
# Out:
# 0        1875.0
# 1       32521.0
# 2        8948.0
# 3       20072.0
# 4       32943.0
#          ...
# 1995    14407.0
# 1996     2105.0
# 1997    35927.0
# 1998    48447.0
# 1999     8433.0
# Name: Sales, Length: 2000, dtype: float64

# %%
df["Sales"].mean()
# Out:
# np.float64(25147.046263345197)

# %%
df["Sales"].fillna(30)
# Out:
# 0        1875.0
# 1       32521.0
# 2        8948.0
# 3       20072.0
# 4       32943.0
#          ...
# 1995    14407.0
# 1996     2105.0
# 1997    35927.0
# 1998    48447.0
# 1999     8433.0
# Name: Sales, Length: 2000, dtype: float64

# %%
df["Sales"]=df["Sales"].fillna(df["Sales"].mean())

# %%
df["Sales"]
# Out:
# 0        1875.0
# 1       32521.0
# 2        8948.0
# 3       20072.0
# 4       32943.0
#          ...
# 1995    14407.0
# 1996     2105.0
# 1997    35927.0
# 1998    48447.0
# 1999     8433.0
# Name: Sales, Length: 2000, dtype: float64

# %%
df["Profit"]
# Out:
# 0       4126.0
# 1       9290.0
# 2       8683.0
# 3       8320.0
# 4       9336.0
#          ...
# 1995    9016.0
# 1996    5292.0
# 1997    2756.0
# 1998    1654.0
# 1999    4718.0
# Name: Profit, Length: 2000, dtype: float64

# %%
df["Profit"].median()
# Out:
# 3526.0

# %%
df["Profit"].fillna(0)
# Out:
# 0       4126.0
# 1       9290.0
# 2       8683.0
# 3       8320.0
# 4       9336.0
#          ...
# 1995    9016.0
# 1996    5292.0
# 1997    2756.0
# 1998    1654.0
# 1999    4718.0
# Name: Profit, Length: 2000, dtype: float64

# %%
df["Profit"]=df["Profit"].fillna(df["Profit"].median())

# %%
df["Profit"]
# Out:
# 0       4126.0
# 1       9290.0
# 2       8683.0
# 3       8320.0
# 4       9336.0
#          ...
# 1995    9016.0
# 1996    5292.0
# 1997    2756.0
# 1998    1654.0
# 1999    4718.0
# Name: Profit, Length: 2000, dtype: float64

# %%
df["City"]
# Out:
# 0          Mumbai
# 1       Bangalore
# 2         Chennai
# 3          Mumbai
# 4       Bangalore
#           ...
# 1995    Bangalore
# 1996        Delhi
# 1997    Mangalore
# 1998        Delhi
# 1999        Kochi
# Name: City, Length: 2000, dtype: object

# %%
df["City"].mode()
# Out:
# 0    Delhi
# Name: City, dtype: object

# %%
df["City"].fillna(0)
# Out:
# 0          Mumbai
# 1       Bangalore
# 2         Chennai
# 3          Mumbai
# 4       Bangalore
#           ...
# 1995    Bangalore
# 1996        Delhi
# 1997    Mangalore
# 1998        Delhi
# 1999        Kochi
# Name: City, Length: 2000, dtype: object

# %%
df["City"]=df["City"].fillna(df["Profit"].mode()[0])

# %%
df["City"]
# Out:
# 0          Mumbai
# 1       Bangalore
# 2         Chennai
# 3          Mumbai
# 4       Bangalore
#           ...
# 1995    Bangalore
# 1996        Delhi
# 1997    Mangalore
# 1998        Delhi
# 1999        Kochi
# Name: City, Length: 2000, dtype: object

# %%
df.isnull().sum()
# Out:
# Transaction_ID      0
# Customer_ID         0
# Customer_Name       0
# Category            0
# Sales               0
# Profit              0
# Quantity            0
# Payment_Status      0
# City                0
# Transaction_Date    0
# dtype: int64

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#       Transaction_ID Customer_ID Customer_Name     Category    Sales  Profit  \
# 0              11317    CUST1134        Anjali    Furniture   1875.0  4126.0
# 1              11001    CUST1177         Sneha   Stationery  32521.0  9290.0
# 2              11069    CUST1478         Sneha         Food   8948.0  8683.0
# 3              11968    CUST1016         Priya    Furniture  20072.0  8320.0
# 4              10530    CUST1321         Priya   Stationery  32943.0  9336.0
# ...              ...         ...           ...          ...      ...     ...
# 1995           10700    CUST1427         Rahul  Electronics  14407.0  9016.0
# 1996           11500    CUST1136          Neha  Electronics   2105.0  5292.0
# 1997           11706    CUST1247         Vivek         Food  35927.0  2756.0
# 1998           10511    CUST1299         Rahul    Furniture  48447.0  1654.0
# 1999           11083    CUST1075          Arun     Clothing   8433.0  4718.0
#
# ...

# %%
df["Category"]=df["Category"].str.title()

# %%
df["Category"]
# Out:
# 0         Furniture
# 1        Stationery
# 2              Food
# 3         Furniture
# 4        Stationery
#            ...
# 1995    Electronics
# 1996    Electronics
# 1997           Food
# 1998      Furniture
# 1999       Clothing
# Name: Category, Length: 1960, dtype: object

# %%
df["Payment_Status"]=df["Payment_Status"].str.title()

# %%
df["Payment_Status"]
# Out:
# 0       Pending
# 1          Paid
# 2        Unpaid
# 3       Pending
# 4          Paid
#          ...
# 1995       Paid
# 1996     Unpaid
# 1997    Pending
# 1998     Unpaid
# 1999    Pending
# Name: Payment_Status, Length: 1960, dtype: object

# %%
df["Category"]=df["Category"].str.strip()

# %%
df["Category"]
# Out:
# 0         Furniture
# 1        Stationery
# 2              Food
# 3         Furniture
# 4        Stationery
#            ...
# 1995    Electronics
# 1996    Electronics
# 1997           Food
# 1998      Furniture
# 1999       Clothing
# Name: Category, Length: 1960, dtype: object

# %%
df["Payment_Status"]=df["Payment_Status"].str.title()

# %%
df["Payment_Status"]
# Out:
# 0       Pending
# 1          Paid
# 2        Unpaid
# 3       Pending
# 4          Paid
#          ...
# 1995       Paid
# 1996     Unpaid
# 1997    Pending
# 1998     Unpaid
# 1999    Pending
# Name: Payment_Status, Length: 1960, dtype: object

# %%
df["City"]=df["City"].str.strip()

# %%
df["City"]
# Out:
# 0          Mumbai
# 1       Bangalore
# 2         Chennai
# 3          Mumbai
# 4       Bangalore
#           ...
# 1995    Bangalore
# 1996        Delhi
# 1997    Mangalore
# 1998        Delhi
# 1999        Kochi
# Name: City, Length: 1960, dtype: object

# %%
df["Transaction_Date"]=pd.to_datetime(df["Transaction_Date"])
df.dtypes
# Out:
# Transaction_ID               int64
# Customer_ID                 object
# Customer_Name               object
# Category                    object
# Sales                      float64
# Profit                     float64
# Quantity                     int64
# Payment_Status              object
# City                        object
# Transaction_Date    datetime64[ns]
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(40)

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#       Transaction_ID Customer_ID Customer_Name     Category    Sales  Profit  \
# 0              11317    CUST1134        Anjali    Furniture   1875.0  4126.0
# 1              11001    CUST1177         Sneha   Stationery  32521.0  9290.0
# 2              11069    CUST1478         Sneha         food   8948.0  8683.0
# 3              11968    CUST1016         Priya    Furniture  20072.0  8320.0
# 4              10530    CUST1321         Priya   Stationery  32943.0  9336.0
# ...              ...         ...           ...          ...      ...     ...
# 1995           10700    CUST1427         Rahul  Electronics  14407.0  9016.0
# 1996           11500    CUST1136          Neha  Electronics   2105.0  5292.0
# 1997           11706    CUST1247         Vivek         Food  35927.0  2756.0
# 1998           10511    CUST1299         Rahul    Furniture  48447.0  1654.0
# 1999           11083    CUST1075          Arun     Clothing   8433.0  4718.0
#
# ...

# %%
df.to_csv("cleaaned_financial_dataset.csv",
          index=False)

# %%
df
# Out:
#       Transaction_ID Customer_ID Customer_Name     Category    Sales  Profit  \
# 0              11317    CUST1134        Anjali    Furniture   1875.0  4126.0
# 1              11001    CUST1177         Sneha   Stationery  32521.0  9290.0
# 2              11069    CUST1478         Sneha         food   8948.0  8683.0
# 3              11968    CUST1016         Priya    Furniture  20072.0  8320.0
# 4              10530    CUST1321         Priya   Stationery  32943.0  9336.0
# ...              ...         ...           ...          ...      ...     ...
# 1995           10700    CUST1427         Rahul  Electronics  14407.0  9016.0
# 1996           11500    CUST1136          Neha  Electronics   2105.0  5292.0
# 1997           11706    CUST1247         Vivek         Food  35927.0  2756.0
# 1998           10511    CUST1299         Rahul    Furniture  48447.0  1654.0
# 1999           11083    CUST1075          Arun     Clothing   8433.0  4718.0
#
# ...

# %%
print("database cleaned successfully")
df
# Out:
# database cleaned successfully
#       Transaction_ID Customer_ID Customer_Name     Category    Sales  Profit  \
# 0              11317    CUST1134        Anjali    Furniture   1875.0  4126.0
# 1              11001    CUST1177         Sneha   Stationery  32521.0  9290.0
# 2              11069    CUST1478         Sneha         food   8948.0  8683.0
# 3              11968    CUST1016         Priya    Furniture  20072.0  8320.0
# 4              10530    CUST1321         Priya   Stationery  32943.0  9336.0
# ...              ...         ...           ...          ...      ...     ...
# 1995           10700    CUST1427         Rahul  Electronics  14407.0  9016.0
# 1996           11500    CUST1136          Neha  Electronics   2105.0  5292.0
# 1997           11706    CUST1247         Vivek         Food  35927.0  2756.0
# 1998           10511    CUST1299         Rahul    Furniture  48447.0  1654.0
# 1999           11083    CUST1075          Arun     Clothing   8433.0  4718.0
#
# ...
