# %%
def simple_interest(p,r,t):
    si=(p*r*t)/100
    return(si)
def compound_interest(p,r,t):
    amount=(p*(1*r/100))**t
    ci=amount-p
    return(ci)
n=int(input("enter the total number of customer:"))
for i in range(n):
    print("\n customer",i+1)
    p=int(input("enter the principal amount:"))
    r=int(input("enter the rate of interest(%):"))
    t=int(input("enter the time:"))
    si=simple_interest(p,r,t)
    ci=compound_interest(p,r,t)
    print("simple interest:",si)
    print("compound interest:",ci)
# Out:
# enter the total number of customer: 3
#  customer 1
# enter the principal amount: 1234
# enter the rate of interest(%): 6
# enter the time: 7
# simple interest: 518.28
# compound interest: 12197332714868.088
#
#  customer 2
# enter the principal amount: 6709
# enter the rate of interest(%): 2
# enter the time: 7
# simple interest: 939.26
# compound interest: 783095111317097.6
#
#  customer 3
# enter the principal amount: 30000
# enter the rate of interest(%): 9
# enter the time: 2
# simple interest: 5400.0
# compound interest: 7260000.0
